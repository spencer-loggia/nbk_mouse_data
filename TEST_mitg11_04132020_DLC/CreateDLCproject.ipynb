# %% [markdown]
# <h1> NOTEBOOK TO CREATE DLC PROJECT, EXTRACT FRAMES & LABEL DATA </h1>
#
# make sure you are running this notebook in properly setup conda enviroment. The nbkGPU enviroment set up on server 2 works properly.

# %%
#Errors here mean there are issues with the enviroment dependencies or PATH configuration
import deeplabcut
import os
task = 'cam1_mitg11_04132020'
experimenter = 'spencer_loggia'

# %% [markdown]
# Get all videos from the provided video source directory

# %%
VIDEO_SOURCE = r'F:\MysoreData\nbk\mitg11_4-13-20\cam1\clips'
all_video = os.listdir(VIDEO_SOURCE)
video = []
NUM_VIDS = 25 #set to len(video) to label all videos
for i in range(0,NUM_VIDS):
    video.append(VIDEO_SOURCE + '\\' + all_video[i])
num_videos = len(video)
print(video)
# Out:
# ['F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_1.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_10.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_100.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_101.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_102.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_103.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_104.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_105.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_106.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_107.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_108.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_109.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_11.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_110.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_111.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_112.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_113.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_114.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_115.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_116.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_117.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_118.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_119.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_12.avi', 'F:\\MysoreData\\nbk\\mitg11_4-13-20\\cam1\\clips\\mitg11-839--04132020085312.avi_clip_120.avi']

# %% [markdown]
# Generate the deeplabcut project, change working directory or else it is created in current directory. The output is the path to the config file.

# %%
path_config_file=deeplabcut.create_new_project(task,experimenter,video, working_directory='.\\', copy_videos=True)
print(path_config_file)
# Out:
# Created "F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos"
# Created "F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data"
# Created "F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\training-datasets"
# Created "F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\dlc-models"
# Copying the videos
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_1.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_10.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_100.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_101.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_102.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_103.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_104.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_105.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_106.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_107.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_108.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_109.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_11.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_110.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_111.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_112.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_113.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_114.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_115.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_116.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_117.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_118.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_119.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_12.avi
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_120.avi
# Generated "F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\config.yaml"
#
# A new project with name cam1_mitg11_04132020-spencer_loggia-2020-04-18 is created at F:\MysoreData\nbk\TEST_mitg11_04132020_DLC and a configurable file (config.yaml) is stored there. Change the parameters in this file to adapt to your project's needs.
#  Once you have changed the configuration file, use the function 'extract_frames' to select frames for labeling.
# . [OPTIONAL] Use the function 'add_new_videos' to add new videos to your project (at any stage).
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\config.yaml

# %% [markdown]
# At this point take a moment to edit the config.yaml file in the new project directory. Set the num2pick variable can be set to change number labeled frames per video. Also edit batch_size to change number of labelled images in each set. <br>
#
# <h1> Now we can extract frames!</h1><br>
# <p>This shows you one frame in the DLC gui from each video in your videos array. It asks you to crop the frame to the area you care about. DLC does not recommend croping to an images size greater than 600X800px <br>
#     Deep lab cut also now selects a number of frames equal to the num2pick configuiration from each video for labelling. These are subdevided into both the training and test sets.<p/>

# %%
#load matplotlib so outputs can be displayed 
# %matplotlib inline 

deeplabcut.extract_frames(path_config_file,'automatic','uniform',crop=True)
# Out:
# Config file read successfully.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_1.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.4  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_10.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.3  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_100.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.4  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_101.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.4  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_102.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 8.67  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_103.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.33  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_104.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.27  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_105.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 3.9  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_106.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.27  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_107.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.37  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_108.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 3.1  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_109.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.27  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_11.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.27  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_110.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.3  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_111.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 3.23  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_112.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 3.27  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_113.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.9  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_114.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.4  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_115.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.27  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_116.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.6  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_117.avi ?
# yes/noyes
# C:\Users\pbs-mysorelab\.conda\envs\nbkGPU\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.93  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_118.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.4  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_119.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.53  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_12.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.7  seconds.
# Do you want to extract (perhaps additional) frames for video: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\videos\mitg11-839--04132020085312.avi_clip_120.avi ?
# yes/noyes
# Extracting frames based on uniform ...
# Uniformly extracting of frames from 0.0  seconds to 2.33  seconds.
#
# Frames were selected.
# You can now label the frames using the function 'label_frames' (if you extracted enough frames for all videos).

# %% [markdown]
# <h1> Now we label the test and training data! </h1>
#
# Once the labelling gui opens, you may have to expand the bottom menu to make sure all buttons are visable.
# There will be a folder with the extracted frames for each video. Go into each and right click to place the current label. Skip a label by choosing the next one on the right hand menu.

# %%
# %gui wx
# %matplotlib inline 
deeplabcut.label_frames(path_config_file)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Users\pbs-mysorelab\.conda\envs\nbkGPU\lib\site-packages\deeplabcut\generate_training_dataset\labeling_toolbox.py in quitButton(self, event)
#     300             self.choiceBox.Clear(True)
#     301             MainFrame.updateZoomPan(self)
# --> 302             MainFrame.browseDir(self, event)
#     303             self.save.Enable(True)
#     304         else:
#
# C:\Users\pbs-mysorelab\.conda\envs\nbkGPU\lib\site-packages\deeplabcut\generate_training_dataset\labeling_toolbox.py in browseDir(self, event)
#     417             dlg.Destroy()
#     418             self.Close(True)
# --> 419         dlg.Destroy()
#     420
#     421 # Enabling the zoom, pan and home buttons
#
# RuntimeError: wrapped C/C++ object of type DirDialog has been deleted
# WARNING: Logging before flag parsing goes to stderr.
# E0418 23:58:06.035152 68180 ioloop.py:763] Exception in callback functools.partial(<function Kernel.enter_eventloop.<locals>.advance_eventloop at 0x0000022FDDC1DBF8>)
# Traceback (most recent call last):
#   File "C:\Users\pbs-mysorelab\.conda\envs\nbkGPU\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\pbs-mysorelab\.conda\envs\nbkGPU\lib\site-packages\ipykernel\kernelbase.py", line 314, in advance_eventloop
#     eventloop(self)
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# The last step is just an automatic check of the labelled data. You should see no errors or something has gone wrong.

# %%
deeplabcut.check_labels(path_config_file) #this creates a subdirectory with the frames + your labels
# Out:
# Creating images with labels by spencer_loggia.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_1_labeled.
# Attention: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_10 does not appear to have labeled data!
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_100_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_101_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_102_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_103_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_104_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_105_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_106_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_107_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_108_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_109_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_11_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_110_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_111_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_112_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_113_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_114_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_115_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_116_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_117_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_118_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_119_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_12_labeled.
# They are stored in the following folder: F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\labeled-data\mitg11-839--04132020085312.avi_clip_120_labeled.
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %% [markdown]
# <h1> Next Steps: </h1>
# <h2> In order to actually train the network, we must use another notebook that runs in a docker container. This allows tensorflow to communicate properly with GPUs in windows </h2>
# run the below cell to get the path_config_file location, copy this path. Open the Docker_DLC_GPU notebook in this directory and set the path_config_file variable there to the same thing.

# %%
print(path_config_file)
# Out:
# F:\MysoreData\nbk\TEST_mitg11_04132020_DLC\cam1_mitg11_04132020-spencer_loggia-2020-04-18\config.yaml
